# %%
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
#import libraries
import requests
import pandas as pd
import time
from selenium.webdriver.support.wait import WebDriverWait
import selenium.webdriver.support.expected_conditions as ec
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains

# %%
# Creation of a new instance of Google Chrome
browser = webdriver.Chrome(executable_path='/Users/johnnyhome/Downloads/chromedriver')

browser.get('https://www.linkedin.com/login')
# Out:
# /var/folders/8v/lrbknlbd3tlct98vvpqnqybr0000gn/T/ipykernel_6277/4204235804.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome(executable_path='/Users/johnnyhome/Downloads/chromedriver')

# %%
# your secret credentials:
import getpass
email = "feteezuk@gmail.com"
password = getpass.getpass()
# Out:
# ········

# %%
# Go to linkedin and login
time.sleep(3)
browser.find_element_by_id('username').send_keys(email)
browser.find_element_by_id('password').send_keys(password)
time.sleep(3)
browser.find_element_by_id('password').send_keys(Keys.RETURN)
#Set Sleep time of 20
time.sleep(3)
# Out:
# /var/folders/8v/lrbknlbd3tlct98vvpqnqybr0000gn/T/ipykernel_6277/3275404169.py:3: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   browser.find_element_by_id('username').send_keys(email)
# /var/folders/8v/lrbknlbd3tlct98vvpqnqybr0000gn/T/ipykernel_6277/3275404169.py:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   browser.find_element_by_id('password').send_keys(password)
# /var/folders/8v/lrbknlbd3tlct98vvpqnqybr0000gn/T/ipykernel_6277/3275404169.py:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   browser.find_element_by_id('password').send_keys(Keys.RETURN)

# %%
#Type Recruiter into text box and hit enter

search_term = "Recruiter"

input = browser.find_element_by_class_name('search-global-typeahead__input')
input.send_keys('Recruiter')
time.sleep(3)
input.send_keys(Keys.RETURN)
# Out:
# /var/folders/8v/lrbknlbd3tlct98vvpqnqybr0000gn/T/ipykernel_6277/3453028063.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   input = browser.find_element_by_class_name('search-global-typeahead__input')

# %%
#CLICK ON PEOPLE to get list of people #
browser.find_element_by_xpath("/html/body/div[5]/div[3]/div/div[2]/section/div/nav/div/ul/li[1]/button").click()



#browser.find_element_by_class_name("search-reusables__filter-pill-button").send_keys(Keys.RETURN)
# Out:
# /var/folders/8v/lrbknlbd3tlct98vvpqnqybr0000gn/T/ipykernel_6277/2769079051.py:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   browser.find_element_by_xpath("/html/body/div[5]/div[3]/div/div[2]/section/div/nav/div/ul/li[1]/button").click()

# %%
title=[]
name = []
number_of_connections=[]
link = []
iter=1
while iter<5:
    the_link="https://www.linkedin.com/search/results/people/?keywords=recruiter&origin=SWITCH_SEARCH_VERTICAL&page="
    the_link = the_link+str(iter).strip()
    browser.get(the_link)

    desc = browser.find_elements_by_class_name("entity-result__title-text")

    x=0
    #Get Name and NUMBER of connections
    while x < len(desc):
        name_and_deg_aray = desc[x].text.split("\n")
        name.append(name_and_deg_aray[0]) #Don't change 0, it grabs name and puts into array
        number_of_connections.append(name_and_deg_aray[3])
        link.append(browser.find_element_by_partial_link_text(name_and_deg_aray[0]).get_attribute("href"))
        x=x+1
    

    # Get JOB Title of reCruiter
    x=0
    title_aray = browser.find_elements_by_class_name('entity-result__primary-subtitle')
    while x < len(title_aray):
        title.append(title_aray[x].text)
        x=x+1
    
   
    iter=iter+1
    
#create DataFrame 
df=pd.DataFrame({'name': name,'title':title, 'number_of_connections':number_of_connections, 'link':link})




#df2 = df2.append(df)
#df2
# Out:
# /var/folders/8v/lrbknlbd3tlct98vvpqnqybr0000gn/T/ipykernel_6277/490349967.py:11: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   desc = browser.find_elements_by_class_name("entity-result__title-text")
# /var/folders/8v/lrbknlbd3tlct98vvpqnqybr0000gn/T/ipykernel_6277/490349967.py:19: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   link.append(browser.find_element_by_partial_link_text(name_and_deg_aray[0]).get_attribute("href"))
# /var/folders/8v/lrbknlbd3tlct98vvpqnqybr0000gn/T/ipykernel_6277/490349967.py:25: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_aray = browser.find_elements_by_class_name('entity-result__primary-subtitle')

# %%
df
# Out:
#                         name  \
# 0            Shakiba Sedighi
# 1              Nathan Briggs
# 2            Christina Hwang
# 3                Selam Desta
# 4        Tess Phan (Reddick)
# 5                  Sherry H.
# 6           Sophie Bracewell
# 7                 Neelu Jain
# 8                Greg Snyder
# 9              Bella Kushnir
# 10                Khin Phong
# 11              Gabrielle S.
# 12              Joan Mendoza
# 13             Jonathan Huie
# 14              Bryce Anable
# 15              Aaron Geiman
# 16                 Mel Mussa
df[df['title'].str.contains("Tech")]
# Out:
#                         name  \
# 0            Shakiba Sedighi
# 2            Christina Hwang
# 3                Selam Desta
# 8                Greg Snyder
# 11              Gabrielle S.
# 12              Joan Mendoza
# 13             Jonathan Huie
# 15              Aaron Geiman
# 19               Katelyn Ewe
# 22            Alan Alcantara
# 23          Kristen Pawloski
# 25            Meredith Alvin
# 26                 Alvin Hui
# 28  Nikki (Winegred) Foreman
# 34              Frank Sperry
# 36          Stephanie Kiraly
# 38               Sandy Dhami
#
#                                                 title  number_of_connections  \
# 0                              Tech Recruiter | Slack  2nd degree connection
# 2                       Technical Recruiter at Stripe  2nd degree connection
# 3                       Technical Recruiter at Google  2nd degree connection
# 8                            Tech Recruiter - Sendoso  2nd degree connection
# 11  Technical Talent Acquisition Specialist | Bloc...  2nd degree connection
# 12                       Technical Recruiter @ Google  2nd degree connection
# 13                    Technical Recruiter at Airtable  2nd degree connection
# 15            Senior Technical Recruiter at StyleSeat  2nd degree connection
# 19                      Technical Recruiter at Podium  2nd degree connection
# 22                   Technical Recruiter @ Linked[In]  2nd degree connection
# 23                 Technical Recruiter at Pinterest 📌  2nd degree connection
# 25                      Technical Recruiter at Stripe  2nd degree connection
# 26         Technical Recruiter at Plaid - I'm hiring!  2nd degree connection
# 28                    Technical Recruiter at LinkedIn  2nd degree connection
# 34  Senior Technical Recruiter @ Nextdoor - We’re ...  2nd degree connection
# 36                     Technical Recruiter at Dropbox  2nd degree connection
# 38                    Technical Recruiter at Autodesk  2nd degree connection
#
#                                                  link
# 0   https://www.linkedin.com/in/shakiba-sedighi-22...
# 2   https://www.linkedin.com/in/christinashwang?mi...
# 3   https://www.linkedin.com/in/selam-desta-aa32a5...
# 8   https://www.linkedin.com/in/greg-snyder-346530...
# 11  https://www.linkedin.com/in/gabrielle-s-7a2785...
# 12  https://www.linkedin.com/in/joanmendoza?miniPr...
# 13  https://www.linkedin.com/in/jonathan-huie?mini...
# 15  https://www.linkedin.com/in/aaron-geiman?miniP...
# 19  https://www.linkedin.com/in/katelyn-ewe?miniPr...
# 22  https://www.linkedin.com/in/alanalc04?miniProf...
# 23  https://www.linkedin.com/in/kjpawloski?miniPro...
# 25  https://www.linkedin.com/in/meredithalvin?mini...
# 26  https://www.linkedin.com/in/huialvin?miniProfi...
# 28  https://www.linkedin.com/in/nikki-winegred-for...
# 34  https://www.linkedin.com/in/franksperry22?mini...
# 36  https://www.linkedin.com/in/stephanie-kiraly-1...
# 38  https://www.linkedin.com/in/sandydhami?miniPro...

# %%
df[df['title'].str.contains("hiring")]
# Out:
#                  name                                          title  \
# 26          Alvin Hui     Technical Recruiter at Plaid - I'm hiring!
# 30  Christina Cartner  Senior Recruiter at Intercom | We're hiring!🚀
#
#     number_of_connections                                               link
# 26  2nd degree connection  https://www.linkedin.com/in/huialvin?miniProfi...
# 30  2nd degree connection  https://www.linkedin.com/in/christina-cartner-...
