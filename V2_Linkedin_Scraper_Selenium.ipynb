# %%
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
#import libraries
import requests
import pandas as pd
import time
from selenium.webdriver.support.wait import WebDriverWait
import selenium.webdriver.support.expected_conditions as ec
from selenium.webdriver.common.by import By

# %%
# Creation of a new instance of Google Chrome
browser = webdriver.Chrome(executable_path='/Users/johnnyhome/Downloads/chromedriver')

browser.get('https://www.linkedin.com/login')
# Out:
# /var/folders/8v/lrbknlbd3tlct98vvpqnqybr0000gn/T/ipykernel_92332/4204235804.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome(executable_path='/Users/johnnyhome/Downloads/chromedriver')

# %%
# your secret credentials:
import getpass
password = getpass.getpass()
# Out:
# ········

# %%
# Go to linkedin and login
time.sleep(3)
browser.find_element_by_id('username').send_keys(email)
browser.find_element_by_id('password').send_keys(password)
time.sleep(3)
browser.find_element_by_id('password').send_keys(Keys.RETURN)
#Set Sleep time of 20
time.sleep(3)
# Out:
# /var/folders/8v/lrbknlbd3tlct98vvpqnqybr0000gn/T/ipykernel_92332/3275404169.py:3: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   browser.find_element_by_id('username').send_keys(email)
# /var/folders/8v/lrbknlbd3tlct98vvpqnqybr0000gn/T/ipykernel_92332/3275404169.py:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   browser.find_element_by_id('password').send_keys(password)
# /var/folders/8v/lrbknlbd3tlct98vvpqnqybr0000gn/T/ipykernel_92332/3275404169.py:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   browser.find_element_by_id('password').send_keys(Keys.RETURN)

# %%
#Type Recruiter into text box and hit enter

search_term = "Recruiter"

input = browser.find_element_by_class_name('search-global-typeahead__input')
input.send_keys('Recruiter')
time.sleep(3)
input.send_keys(Keys.RETURN)
# Out:
# /var/folders/8v/lrbknlbd3tlct98vvpqnqybr0000gn/T/ipykernel_92332/3453028063.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   input = browser.find_element_by_class_name('search-global-typeahead__input')

# %%
#CLICK ON PEOPLE to get list of people #
browser.find_element_by_xpath("/html/body/div[6]/div[3]/div/div[2]/section/div/nav/div/ul/li[1]/button").click()



#browser.find_element_by_class_name("search-reusables__filter-pill-button").send_keys(Keys.RETURN)
# Out:
# /var/folders/8v/lrbknlbd3tlct98vvpqnqybr0000gn/T/ipykernel_92332/1150977234.py:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   browser.find_element_by_xpath("/html/body/div[6]/div[3]/div/div[2]/section/div/nav/div/ul/li[1]/button").click()

# %%
desc = browser.find_elements_by_class_name("entity-result__title-text")
x=0
name = []
number_of_connections=[]
link = []

#Get Name and NUMBER of connections
while x < len(desc):
 name_and_deg_aray = desc[x].text.split("\n")
 name.append(name_and_deg_aray[0]) #Don't change 0, it grabs name and puts into array
 number_of_connections.append(name_and_deg_aray[3])
 link.append(browser.find_element_by_partial_link_text(name_and_deg_aray[0]).get_attribute("href"))
 x=x+1

# Get JOB Title of reCruiter
title=[]
x=0
title_aray = browser.find_elements_by_class_name('entity-result__primary-subtitle')
while x < len(title_aray):
 title.append(title_aray[x].text)
 x=x+1


#create DataFrame 
df=pd.DataFrame({'name': name,'title':title, 'number_of_connections':number_of_connections, 'link':link})


df
# Out:
# /var/folders/8v/lrbknlbd3tlct98vvpqnqybr0000gn/T/ipykernel_92332/2660154188.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   desc = browser.find_elements_by_class_name("entity-result__title-text")
# /var/folders/8v/lrbknlbd3tlct98vvpqnqybr0000gn/T/ipykernel_92332/2660154188.py:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   link.append(browser.find_element_by_partial_link_text(name_and_deg_aray[0]).get_attribute("href"))
# /var/folders/8v/lrbknlbd3tlct98vvpqnqybr0000gn/T/ipykernel_92332/2660154188.py:18: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_aray = browser.find_elements_by_class_name('entity-result__primary-subtitle')
#                   name                                              title  \
# 0      Shakiba Sedighi                             Tech Recruiter | Slack
# 1      Christina Hwang                      Technical Recruiter at Stripe
# 2        Nathan Briggs                                          Recruiter
# 3  Tess Phan (Reddick)                                  Recruiter at ON24
# 4     Sophie Bracewell                                Recruiter at Airbnb
# 5            Sherry H.                                Executive Recruiter
# 6         Gabrielle S.  Technical Talent Acquisition Specialist | Bloc...
# 7          Selam Desta                      Technical Recruiter at Google
# 8     Kristen Pawloski                 Technical Recruiter at Pinterest 📌
# 9         Aaron Geiman            Senior Technical Recruiter at StyleSeat
#
#    number_of_connections                                               link
# 0  2nd degree connection  https://www.linkedin.com/in/shakiba-sedighi-22...
# 1  2nd degree connection  https://www.linkedin.com/in/christinashwang?mi...
# 2  2nd degree connection  https://www.linkedin.com/in/nabriggs?miniProfi...
# 3  2nd degree connection  https://www.linkedin.com/in/tess-phan-reddick-...
# 4  2nd degree connection  https://www.linkedin.com/in/sophiebracewell?mi...
# 5  2nd degree connection  https://www.linkedin.com/in/sherry-h-28295b1?m...
# 6  2nd degree connection  https://www.linkedin.com/in/gabrielle-s-7a2785...
# 7  2nd degree connection  https://www.linkedin.com/in/selam-desta-aa32a5...
# 8  2nd degree connection  https://www.linkedin.com/in/kjpawloski?miniPro...
# 9  2nd degree connection  https://www.linkedin.com/in/aaron-geiman?miniP...

# %%
#'This is page 2' of search results
#browser.execute_script("window.scrollTo(150, document.body.scrollHeight);")
#selector = []


 # THis works   
#browser.find_element_by_css_selector('li.selected').next()
#browser.find_elements_by_partial_link_text('Next')

#USE THIS AS SCRIPT TO 
# 1. SCROLLS TO BOTTOM OF PAGE
browser.execute_script("window.scrollTo(0,document.body.scrollHeight)")
# 2. CLICKS NEXT
browser.find_element_by_class_name("artdeco-button--icon-right").click()
# Out:
# /var/folders/8v/lrbknlbd3tlct98vvpqnqybr0000gn/T/ipykernel_92332/3661317161.py:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   browser.find_element_by_class_name("artdeco-button--icon-right").click()

# %%
desc = browser.find_elements_by_class_name("entity-result__title-text")

x=0
name = []
number_of_connections=[]
link = []

#Get Name and NUMBER of connections
while x < len(desc):
 name_and_deg_aray = desc[x].text.split("\n")
 name.append(name_and_deg_aray[0]) #Don't change 0, it grabs name and puts into array
 number_of_connections.append(name_and_deg_aray[3])
 link.append(browser.find_element_by_partial_link_text(name_and_deg_aray[0]).get_attribute("href"))
 x=x+1

# Get JOB Title of reCruiter
title=[]
x=0
title_aray = browser.find_elements_by_class_name('entity-result__primary-subtitle')
while x < len(title_aray):
 title.append(title_aray[x].text)
 x=x+1


#create DataFrame 
df2=pd.DataFrame({'name': name,'title':title, 'number_of_connections':number_of_connections, 'link':link})



df2 = df2.append(df)
df2
# Out:
# /var/folders/8v/lrbknlbd3tlct98vvpqnqybr0000gn/T/ipykernel_92332/1891734898.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   desc = browser.find_elements_by_class_name("entity-result__title-text")
# /var/folders/8v/lrbknlbd3tlct98vvpqnqybr0000gn/T/ipykernel_92332/1891734898.py:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   link.append(browser.find_element_by_partial_link_text(name_and_deg_aray[0]).get_attribute("href"))
# /var/folders/8v/lrbknlbd3tlct98vvpqnqybr0000gn/T/ipykernel_92332/1891734898.py:19: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_aray = browser.find_elements_by_class_name('entity-result__primary-subtitle')
#                   name                                              title  \
# 0        Jonathan Huie                    Technical Recruiter at Airtable
# 1        Neil Warlicht                                Executive Recruiter
# 2         Danna Hughes           Software Engineering Recruiter at Google
# 3          Samantha J.                  Business Recruiter at Pinterest 📌
# 4        Bella Kushnir                                  Recruiter at Meta
# 5        Nicole Sasson                      Technical Recruiter at Google
# 6          Katelyn Ewe                      Technical Recruiter at Podium
# 7         Joan Mendoza                       Technical Recruiter @ Google
# 8      Korina Lealiiee                               Recruiter at Sendoso
# 9           Khin Phong                             Recruiter at Robinhood
# 0      Shakiba Sedighi                             Tech Recruiter | Slack
# 1      Christina Hwang                      Technical Recruiter at Stripe
# 2        Nathan Briggs                                          Recruiter
# 3  Tess Phan (Reddick)                                  Recruiter at ON24
# 4     Sophie Bracewell                                Recruiter at Airbnb
# 5            Sherry H.                                Executive Recruiter
# 6         Gabrielle S.  Technical Talent Acquisition Specialist | Bloc...
# 7          Selam Desta                      Technical Recruiter at Google
# 8     Kristen Pawloski                 Technical Recruiter at Pinterest 📌
# 9         Aaron Geiman            Senior Technical Recruiter at StyleSeat
#
#    number_of_connections                                               link
# 0  2nd degree connection  https://www.linkedin.com/in/jonathan-huie?mini...
# 1  2nd degree connection  https://www.linkedin.com/in/neilwarlicht?miniP...
# 2  2nd degree connection  https://www.linkedin.com/in/danna-hughes-4539a...
# 3  2nd degree connection  https://www.linkedin.com/in/samanthaejames?min...
# 4  2nd degree connection  https://www.linkedin.com/in/bella-kushnir-8563...
# 5  2nd degree connection  https://www.linkedin.com/in/nicolesasson?miniP...
# 6  2nd degree connection  https://www.linkedin.com/in/katelyn-ewe?miniPr...
# 7  2nd degree connection  https://www.linkedin.com/in/joanmendoza?miniPr...
# 8  2nd degree connection  https://www.linkedin.com/in/korina-lealiiee-78...
# 9  2nd degree connection  https://www.linkedin.com/in/khin-phong-165b461...
# 0  2nd degree connection  https://www.linkedin.com/in/shakiba-sedighi-22...
# 1  2nd degree connection  https://www.linkedin.com/in/christinashwang?mi...
# 2  2nd degree connection  https://www.linkedin.com/in/nabriggs?miniProfi...
# 3  2nd degree connection  https://www.linkedin.com/in/tess-phan-reddick-...
# 4  2nd degree connection  https://www.linkedin.com/in/sophiebracewell?mi...
# 5  2nd degree connection  https://www.linkedin.com/in/sherry-h-28295b1?m...
# 6  2nd degree connection  https://www.linkedin.com/in/gabrielle-s-7a2785...
# 7  2nd degree connection  https://www.linkedin.com/in/selam-desta-aa32a5...
# 8  2nd degree connection  https://www.linkedin.com/in/kjpawloski?miniPro...
# 9  2nd degree connection  https://www.linkedin.com/in/aaron-geiman?miniP...

# %%
#'This is page 2' of search results

#This works======
#browser.find_element_by_css_selector('[aria-label="Page {}"').format()

#USE THIS AS SCRIPT TO 
# 1. SCROLLS TO BOTTOM OF PAGE
browser.execute_script("window.scrollTo(0,document.body.scrollHeight)")
# 2. CLICKS NEXT
browser.find_element_by_class_name("artdeco-button--icon-right").click()
# Out:
# /var/folders/8v/lrbknlbd3tlct98vvpqnqybr0000gn/T/ipykernel_92332/1590505964.py:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   browser.find_element_by_class_name("artdeco-button--icon-right").click()

# %%
desc = browser.find_elements_by_class_name("entity-result__title-text")

x=0
name = []
number_of_connections=[]
link = []

#Get Name and NUMBER of connections
while x < len(desc):
 name_and_deg_aray = desc[x].text.split("\n")
 name.append(name_and_deg_aray[0]) #Don't change 0, it grabs name and puts into array
 number_of_connections.append(name_and_deg_aray[3])
 link.append(browser.find_element_by_partial_link_text(name_and_deg_aray[0]).get_attribute("href"))
 x=x+1

# Get JOB Title of reCruiter
title=[]
x=0
title_aray = browser.find_elements_by_class_name('entity-result__primary-subtitle')
while x < len(title_aray):
 title.append(title_aray[x].text)
 x=x+1


#create DataFrame 
df3=pd.DataFrame({'name': name,'title':title, 'number_of_connections':number_of_connections, 'link':link})




LIST = df3.append(df2)
LIST
# Out:
# /var/folders/8v/lrbknlbd3tlct98vvpqnqybr0000gn/T/ipykernel_92332/4126921954.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   desc = browser.find_elements_by_class_name("entity-result__title-text")
# /var/folders/8v/lrbknlbd3tlct98vvpqnqybr0000gn/T/ipykernel_92332/4126921954.py:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   link.append(browser.find_element_by_partial_link_text(name_and_deg_aray[0]).get_attribute("href"))
# /var/folders/8v/lrbknlbd3tlct98vvpqnqybr0000gn/T/ipykernel_92332/4126921954.py:19: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   title_aray = browser.find_elements_by_class_name('entity-result__primary-subtitle')
#                     name                                              title  \
# 0          Maryann Hamed        Executive Recruiter at Heidrick & Struggles
# 1  Danica Robinson-Liles                          Global Recruiter @ Airbnb
# 2            Greg Snyder                           Tech Recruiter - Sendoso
# 3         Alyssa Cavalli                    Senior Recruiter at TripActions
# 4    Jasmine Nouri, Esq.                  Associate Recruiter at Salesforce
# 5             Neelu Jain                     Leadership Recruiter - Product
# 6           Bryce Anable                      Senior Recruiter at Amplitude
# 7             Shanna Zhu             Technical Recruiter at Google Research
# 8          Alyssa Moreno               Technical Recruiter at Thrive Global
# 9      Christina Cartner      Senior Recruiter at Intercom | We're hiring!🚀
# 0          Jonathan Huie                    Technical Recruiter at Airtable
# 1          Neil Warlicht                                Executive Recruiter
# 2           Danna Hughes           Software Engineering Recruiter at Google
# 3            Samantha J.                  Business Recruiter at Pinterest 📌
# 4          Bella Kushnir                                  Recruiter at Meta
# 5          Nicole Sasson                      Technical Recruiter at Google
# 6            Katelyn Ewe                      Technical Recruiter at Podium
# 7           Joan Mendoza                       Technical Recruiter @ Google
# 8        Korina Lealiiee                               Recruiter at Sendoso
# 9             Khin Phong                             Recruiter at Robinhood
# 0        Shakiba Sedighi                             Tech Recruiter | Slack
# 1        Christina Hwang                      Technical Recruiter at Stripe
# 2          Nathan Briggs                                          Recruiter
# 3    Tess Phan (Reddick)                                  Recruiter at ON24
